# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv(r'/Users/ranjitsingh/Documents/Dataset/Nexthikes-Project2/dataset_1 - dataset_1.csv')

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
df.shape
# Out:
# (610, 10)

# %%
df['instant'].nunique()
# Out:
# 610

# %% [markdown]
# ## The data does not contain any missing values; however, the date column is currently in object format and needs to be converted to a date type.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %% [markdown]
# ## Using value_counts will help to identify the different format of dates available in the data set.
# ## Analyzing Date Range also confirms data is only for January 2011.

# %%
df['dteday'].value_counts(dropna= False)
# Out:
# dteday
# 01-01-2011    24
# 09-01-2011    24
# 21-01-2011    24
# 20-01-2011    24
# 17-01-2011    24
# 16-01-2011    24
# 13-01-2011    24
# 10-01-2011    24
# 15-01-2011    24
# 08-01-2011    24
# 05-01-2011    23
# 25-01-2011    23
# 24-01-2011    23
# 23-01-2011    23
# 22-01-2011    23
# 04-01-2011    23
# 19-01-2011    23
# 06-01-2011    23
# 02-01-2011    23
# 14-01-2011    23
# 07-01-2011    23
# 11-01-2011    22
# 03-01-2011    22
# 12-01-2011    22
# 26-01-2011    16
# 28-01-2011    15
# 18-01-2011    12
# 27-01-2011     8
# Name: count, dtype: int64

# %% [markdown]
# ## Standardizing the Date Column by Converting it to Datetime Format

# %%
df['dteday'] = df['dteday'].astype('datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB

# %% [markdown]
# ## Value_counts count the occurrences of unique values in each column of DataFrame

# %%
df['season'].value_counts(dropna= False)
# Out:
# season
# 1    610
# Name: count, dtype: int64

# %%
df['holiday'].value_counts(dropna= False)
# Out:
# holiday
# False    586
# True      24
# Name: count, dtype: int64

# %%
df['yr'].value_counts(dropna= False)
# Out:
# yr
# 0    610
# Name: count, dtype: int64

# %%
df['mnth'].value_counts(dropna= False)
# Out:
# mnth
# 1    610
# Name: count, dtype: int64

# %%
df['hr'].value_counts(dropna= False)
# Out:
# hr
# 12    27
# 17    27
# 16    27
# 15    27
# 14    27
# 13    27
# 1     26
# 22    26
# 21    26
# 20    26
# 19    26
# 18    26
# 0     26
# 11    26
# 10    26
# 9     26
# 8     26
# 7     26
# 6     26
# 23    26
# 5     24
# 2     24
# 4     20
# 3     16
# Name: count, dtype: int64

# %%
df['holiday'].value_counts(dropna= False)
# Out:
# holiday
# False    586
# True      24
# Name: count, dtype: int64

# %%
df['weekday'].value_counts(dropna= False)
# Out:
# weekday
# 6    95
# 0    94
# 1    93
# 5    85
# 3    84
# 2    80
# 4    79
# Name: count, dtype: int64

# %%
df['weathersit'].value_counts(dropna= False)
# Out:
# weathersit
# 1    368
# 2    194
# 3     47
# 4      1
# Name: count, dtype: int64

# %%
df['temp'].value_counts(dropna= False)
# Out:
# temp
# 0.20    89
# 0.16    84
# 0.22    79
# 0.14    56
# 0.18    54
# 0.24    40
# 0.26    32
# 0.12    29
# 0.10    22
# 0.30    19
# 0.04    14
# 0.32    13
# 0.06    11
# 0.28    10
# 0.02    10
# 0.08     9
# 0.40     8
# 0.36     8
# 0.46     6
# 0.42     6
# 0.34     5
# 0.44     3
# 0.38     3
# Name: count, dtype: int64

# %%
df1 = pd.read_csv(r'/Users/ranjitsingh/Documents/Dataset/Nexthikes-Project2/dataset_2.xlsx - dataset_2.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
df1.shape
# Out:
# (610, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %% [markdown]
# ## Column [atemp] has missing values

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
df1['atemp'].describe()
# Out:
# count    599.000000
# mean       0.199935
# std        0.078836
# min        0.000000
# 25%        0.151500
# 50%        0.197000
# 75%        0.242400
# max        0.454500
# Name: atemp, dtype: float64

# %% [markdown]
# ## KDE (from sns.histplot) helps determine whether the data follows a normal distribution.
# ## If the shape of the distribution resembles a bell curve, it is considered a normal distribution, also known as the Gaussian distribution, which is symmetric around the mean.
# ## Note: A normal distribution does not imply the absence of outliers.

# %%
sns.histplot(df1['atemp'],bins=30, kde=True)
plt.show()

# %% [markdown]
# ## The boxplot is useful for identifying any outliers in the data.
# ## The dots in the plot represent the outliers.

# %%
sns.boxplot(df1['atemp'])
plt.show()

# %%
## Mean: Use with normally distributed data without outliers
## Median: Prefer for skewed data or data with outliers.

# %%
## removing outliers to find the mean

# %% [markdown]
# ## Since df1['atemp'] contains missing values, we will explore multiple methods to determine the best approach for filling the NaN values.
# ## To preserve the integrity of the original dataset, I prefer creating a copy of the df1['atemp'] column. This allows us to experiment with different imputation techniques without modifying the original DataFrame.

# %%
df_temp = df1[['atemp']].copy()

# %%
df_temp.shape
# Out:
# (610, 1)

# %% [markdown]
# ## Removing outliers from new df_atemp['atemp']

# %%
Q1 = df_temp['atemp'].quantile(0.25)
Q3= df_temp['atemp'].quantile(0.75)
print('Q1 = ', Q1)
print('Q3 = ', Q3)

Lower_limit =Q1-1.5*(Q3-Q1)
Upper_limit =Q3+1.5*(Q3-Q1)
print('Lower_limit = ', Lower_limit)
print('Upper_limit = ',Upper_limit)
# Out:
# Q1 =  0.1515
# Q3 =  0.2424
# Lower_limit =  0.015149999999999969
# Upper_limit =  0.37875000000000003

# %%
df_temp_no_outlier = df_temp[(df_temp['atemp']>=Lower_limit)&(df_temp['atemp']<=Upper_limit)]
df_temp_no_outlier.shape
# Out:
# (575, 1)

# %% [markdown]
# ## Below mean is calculated after removing outliers from the data
# ## The reason for calculating the mean without outliers is based on a correct statistical approach. When filling missing values with the mean, it is crucial to first remove outliers to ensure data accuracy. This is because extreme values (very high or very low) can significantly skew the mean, leading to misleading results.
# ## However, the median represents the middle value of a dataset, making it resistant to the impact of outliers. Therefore, even if outliers are present, the median remains unaffected.

# %%
mean = df_temp_no_outlier['atemp'].mean()
mean
# Out:
# 0.19210156521739127

# %%
median = df_temp['atemp'].median()
median
# Out:
# 0.197

# %% [markdown]
# ## After performing fillna(mode),i concluded not use mode function to fill missing values, as it only fills the first NaN with the first mode value, leaving the rest unchanged.Instead, we can use random.choice(modes) which is similar to sample function, which is performed in the next step.

# %%
#mode = df_temp['atemp'].mode()
#mode

# %% [markdown]
# ## Filling missing values with the standard deviation (std) is not a common practice, as the standard deviation is a measure of the spread or dispersion of a dataset, not a central value.

# %%
#std = df_temp['atemp'].std()
#std

# %% [markdown]
# ## Common Approaches to Filling Missing Values Mean,Median,Mode, random values

# %%
def fill_na(col,var,val):
    df_temp[col+var]= df_temp[col].fillna(val)

# %%
fill_na('atemp','_mean',mean)

# %%
fill_na('atemp','_median',median)

# %%
#fill_na('atemp','_mode',mode)

# %%
#fill_na('atemp','_std',std)

# %%
df_temp.head()
# Out:
#     atemp  atemp_mean  atemp_median
# 0  0.2879      0.2879        0.2879
# 1  0.2727      0.2727        0.2727
# 2  0.2727      0.2727        0.2727
# 3  0.2879      0.2879        0.2879
# 4  0.2879      0.2879        0.2879

# %% [markdown]
# ## Now filling nan value with random selected values

# %%
df_temp['atemp'].isnull().sum()
# Out:
# 11

# %%
random_value = df_temp['atemp'].sample(11,random_state=11)
random_value
# Out:
# 220    0.1364
# 169    0.1818
# 49     0.1364
# 270    0.1818
# 277    0.1212
# 419    0.3182
# 221    0.1818
# 317    0.2273
# 344    0.3030
# 609    0.2576
# 33     0.3485
# Name: atemp, dtype: float64

# %%
random_value.index
# Out:
# Index([220, 169, 49, 270, 277, 419, 221, 317, 344, 609, 33], dtype='int64')

# %%
df_temp[df_temp['atemp'].isnull()].index
# Out:
# Index([8, 17, 23, 28, 32, 37, 43, 48, 58, 65, 69], dtype='int64')

# %% [markdown]
# ## It is crucial to match the index of the randomly selected values with the index of the missing values.
# ## Failing to do so may result in unintended replacements of existing values instead of correctly filling the missing ones.

# %%
random_value.index = df_temp[df_temp['atemp'].isnull()].index

# %%
random_value.index
# Out:
# Index([8, 17, 23, 28, 32, 37, 43, 48, 58, 65, 69], dtype='int64')

# %%
df_temp[df_temp['atemp'].isnull()].index
# Out:
# Index([8, 17, 23, 28, 32, 37, 43, 48, 58, 65, 69], dtype='int64')

# %%
df_temp['atemp_random_values'] = df_temp['atemp'].fillna(random_value)

# %%
df_temp.head()
# Out:
#     atemp  atemp_mean  atemp_median  atemp_random_values
# 0  0.2879      0.2879        0.2879               0.2879
# 1  0.2727      0.2727        0.2727               0.2727
# 2  0.2727      0.2727        0.2727               0.2727
# 3  0.2879      0.2879        0.2879               0.2879
# 4  0.2879      0.2879        0.2879               0.2879

# %% [markdown]
# ## Calculating the standard deviation of the original data vs. the standard deviation of the data after filling missing values.
# ## The goal of applying various imputation methods is to determine which approach results in a standard deviation closest to the original, ensuring the most accurate data representation.

# %%
print("STD of col atemp :      ",df_temp['atemp'].std())
print("STD of col atemp_mean:  ",df_temp['atemp_mean'].std()) 
print("STD of col atemp_median:",df_temp['atemp_median'].std()) 
print("STD of col atemp_random_values:",df_temp['atemp_random_values'].std())
##print("STD of col atemp_mode:  ",df_temp['atemp_mode'].std())
##print("STD of col atemp_std:   ",df_temp['atemp_std'].std())
# Out:
# STD of col atemp :       0.07883563805393563
# STD of col atemp_mean:   0.07812737883578995
# STD of col atemp_median: 0.07812139117854042
# STD of col atemp_random_values: 0.07881049535803075

# %% [markdown]
# ## The graphs below provide a clearer visualization to help determine the best method for filling missing values in this dataset.
# ## The first plot displays all columns in different colors, but due to the close comparison, it does not provide a clear distinction.
# ## To address this, the following plots focus on comparing the original data with the calculated columns, offering a more precise evaluation.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df_temp['atemp'].plot(kind='kde', ax=ax)
df_temp['atemp_mean'].plot(kind='kde', ax=ax, color='red')
df_temp['atemp_median'].plot(kind='kde', ax=ax, color='yellow')
df_temp['atemp_random_values'].plot(kind='kde', ax=ax, color='green')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
plt.show()

# %% [markdown]
# ## 'atemp' VS 'atemp_mean'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df_temp['atemp'].plot(kind='kde', ax=ax)
df_temp['atemp_mean'].plot(kind='kde', ax=ax, color='red')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
plt.show()

# %% [markdown]
# ## 'atemp' VS 'atemp_median'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df_temp['atemp'].plot(kind='kde', ax=ax)
df_temp['atemp_median'].plot(kind='kde', ax=ax, color='yellow')

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
plt.show()

# %% [markdown]
# ## 'atemp' VS 'atemp_random_values'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df_temp['atemp'].plot(kind='kde', ax=ax)
df_temp['atemp_random_values'].plot(kind='kde', ax=ax, color='green')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
plt.show()

# %% [markdown]
# ## After applying all the suitable methods to fill null, the std of atemp_random_values and plot is very close original data atemp.
# ## So i will choose to fill na values with random values
# ## So final step i will copy the data to the original df

# %%
df1['atemp'] = df_temp[['atemp_random_values']].copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       610 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %%
df1.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
df.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %% [markdown]
# ## Next step to merge the df and df1

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'instant', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp'],
#       dtype='object')

# %%
df1 = df1.drop('Unnamed: 0', axis=1)

# %%
df1.shape
# Out:
# (610, 7)

# %%
df2 = pd.merge(df,df1,on ='instant',how = 'outer')
df2.shape
# Out:
# (610, 16)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  atemp       610 non-null    float64
#  11  hum         610 non-null    float64
#  12  windspeed   610 non-null    float64
#  13  casual      610 non-null    int64
#  14  registered  610 non-null    int64
#  15  cnt         610 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 72.2 KB

# %%
df2.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %%
df2 = df2.drop_duplicates(keep='last')

# %%
df2.shape
# Out:
# (610, 16)

# %%
df2.to_csv('/Users/ranjitsingh/Documents/Nexthikes-Project2/merged_data1.csv', index = False)
